# %%
import pickle


with open('/home/manu.puthiyadath/projects/MvSMPLfitting/output/results/0001/0/000.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'betas': array([[ 0.09156481,  0.36510772,  0.00400583, -0.01606641, -0.07088365,
#          -0.03074145,  0.02304815,  0.02620437, -0.02408106, -0.03366284]],
#        dtype=float32),
#  'global_orient': array([[-0.14934078,  2.865398  ,  0.55371535]], dtype=float32),
#  'transl': array([[-1.4190578 ,  0.24791707,  4.79073   ]], dtype=float32),
#  'scale': array([-1.3692352], dtype=float32),
#  'loss': 174.05397033691406,
#  'pose_embedding': array([[-0.4190218 ,  0.01398546, -0.30960113, -0.178701  ,  0.03242318,
#          -0.30534732, -0.6311018 , -0.04665108, -0.1008901 , -0.96546847,
#          -0.07435702, -0.48289979,  0.01797294, -0.80685914, -0.4272709 ,
#           0.08483826,  0.01901408,  0.13220973, -0.2906261 ,  0.04712275,
#           0.04054367,  0.3806237 ,  0.15588078,  0.20584711, -0.11384246,
#          -0.06791963, -0.12053665,  0.33087108, -0.09923936,  0.4910367 ,
#          -0.4748357 ,  0.0554843 ]], dtype=float32),
# ...

# %%
data['betas']
# Out:
# array([[ 0.09156481,  0.36510772,  0.00400583, -0.01606641, -0.07088365,
#         -0.03074145,  0.02304815,  0.02620437, -0.02408106, -0.03366284]],
#       dtype=float32)

# %%
import numpy as np
np.round(data['betas'], 4)
# Out:
# array([[ 0.0916,  0.3651,  0.004 , -0.0161, -0.0709, -0.0307,  0.023 ,
#          0.0262, -0.0241, -0.0337]], dtype=float32)
