# %%
from matplotlib import image 
from matplotlib import pyplot as plt

# %%
my_img = image.imread('/home/manu.puthiyadath/projects/MvSMPLfitting/data/images/0000/Camera00/00001.png')
plt.imshow(my_img)

# %%
my_img.shape
# Out:
# (1920, 1080, 3)

# %%
## read the keypoints from the keypoints json file
import json
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

f = open('/home/manu.puthiyadath/projects/RVH_Mesh_Registration/data/mesh_2/2D_pose.json')
data = json.load(f)
print(data.keys())
keypoints = data['0']['pose_keypoints_2d']
keypoints = np.array(keypoints)
# Out:
# dict_keys(['0', '1', '2', '3', '4', '5', '6', '7', '8'])

# %%
keypoints
# Out:
# array([[5.54028015e+02, 3.45480957e+02, 9.04480457e-01],
#        [5.57948669e+02, 5.41928284e+02, 9.04082060e-01],
#        [4.21644714e+02, 5.37941833e+02, 8.51514280e-01],
#        [3.33385925e+02, 7.58684082e+02, 8.37341249e-01],
#        [2.57207245e+02, 9.63156006e+02, 8.03294659e-01],
#        [6.90499146e+02, 5.41987183e+02, 8.44476998e-01],
#        [7.54671997e+02, 7.66701233e+02, 8.14850807e-01],
#        [8.06715027e+02, 9.79287842e+02, 8.77742469e-01],
#        [5.37984741e+02, 9.75221802e+02, 7.56389141e-01],
#        [4.45690399e+02, 9.71222290e+02, 7.01345861e-01],
#        [4.09674103e+02, 1.30812195e+03, 7.84904659e-01],
#        [3.89533020e+02, 1.58495776e+03, 7.63551056e-01],
#        [6.30178650e+02, 9.79254150e+02, 7.42043495e-01],
#        [6.22194641e+02, 1.32014124e+03, 7.96026647e-01],
#        [6.18195740e+02, 1.56884436e+03, 7.97459602e-01],
#        [5.25981812e+02, 3.25363678e+02, 8.97718012e-01],
#        [5.90029358e+02, 3.25367950e+02, 9.05004680e-01],
#        [4.89789612e+02, 3.61509949e+02, 8.34282398e-01],
#        [6.26176636e+02, 3.57507355e+02, 8.68052304e-01],
#        [6.42316345e+02, 1.68121680e+03, 8.00209761e-01],
#        [6.78426880e+02, 1.66511926e+03, 7.57864296e-01],
#        [5.94105774e+02, 1.58893982e+03, 6.65010929e-01],
#        [3.73585571e+02, 1.68511414e+03, 7.71973908e-01],
#        [3.37510223e+02, 1.66516748e+03, 7.58457601e-01],
#        [4.01580841e+02, 1.60497034e+03, 6.04988396e-01]])

# %%
# Out:
# [[554.0280151367188, 345.48095703125, 0.9044804573059082],
#  [557.9486694335938, 541.9282836914062, 0.9040820598602295],
#  [421.64471435546875, 537.9418334960938, 0.8515142798423767],
#  [333.38592529296875, 758.68408203125, 0.8373412489891052],
#  [257.2072448730469, 963.156005859375, 0.8032946586608887],
#  [690.4991455078125, 541.9871826171875, 0.8444769978523254],
#  [754.6719970703125, 766.7012329101562, 0.8148508071899414],
#  [806.7150268554688, 979.287841796875, 0.8777424693107605],
#  [537.9847412109375, 975.2218017578125, 0.7563891410827637],
#  [445.6903991699219, 971.2222900390625, 0.7013458609580994],
#  [409.6741027832031, 1308.1219482421875, 0.7849046587944031],
#  [389.53302001953125, 1584.957763671875, 0.7635510563850403],
#  [630.1786499023438, 979.254150390625, 0.7420434951782227],
#  [622.1946411132812, 1320.1412353515625, 0.7960266470909119],
#  [618.1957397460938, 1568.8443603515625, 0.797459602355957],
#  [525.9818115234375, 325.3636779785156, 0.8977180123329163],
#  [590.0293579101562, 325.3679504394531, 0.9050046801567078],
#  [489.78961181640625, 361.50994873046875, 0.834282398223877],
#  [626.1766357421875, 357.5073547363281, 0.8680523037910461],
#  [642.3163452148438, 1681.216796875, 0.8002097606658936],
#  [678.4268798828125, 1665.1192626953125, 0.7578642964363098],
#  [594.1057739257812, 1588.9398193359375, 0.665010929107666],
#  [373.5855712890625, 1685.1141357421875, 0.7719739079475403],
#  [337.5102233886719, 1665.16748046875, 0.758457601070404],
#  [401.5808410644531, 1604.9703369140625, 0.6049883961677551]]

# %%
plt.imshow(my_img)
# plt.plot(2525250, 2525250, "og", markersize=251)  # og:shorthand for green circle
# plt.scatter(keypoints[:, 0], keypoints[:, 1], c="r", s=251)  # c:color, s:size
plt.scatter(keypoints[25, 0], keypoints[25, 1], c="r", s=10)  # c:color, s:size
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/manu.puthiyadath/projects/MvSMPLfitting/code/notebooks/openpose_keypoints_on_img.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c6569612d45787465726e616c227d/home/manu.puthiyadath/projects/MvSMPLfitting/code/notebooks/openpose_keypoints_on_img.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> plt.imshow(my_img)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c6569612d45787465726e616c227d/home/manu.puthiyadath/projects/MvSMPLfitting/code/notebooks/openpose_keypoints_on_img.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # plt.plot(2525250, 2525250, "og", markersize=251)  # og:shorthand for green circle
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c6569612d45787465726e616c227d/home/manu.puthiyadath/projects/MvSMPLfitting/code/notebooks/openpose_keypoints_on_img.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # plt.scatter(keypoints[:, 0], keypoints[:, 1], c="r", s=251)  # c:color, s:size
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c6569612d45787465726e616c227d/home/manu.puthiyadath/projects/MvSMPLfitting/code/notebooks/openpose_keypoints_on_img.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> plt.scatter(keypoints[25, 0], keypoints[25, 1], c="r", s=10)  # c:color, s:size
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c6569612d45787465726e616c227d/home/manu.puthiyadath/projects/MvSMPLfitting/code/notebooks/openpose_keypoints_on_img.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> plt.show()
#
# IndexError: index 25 is out of bounds for axis 0 with size 25
